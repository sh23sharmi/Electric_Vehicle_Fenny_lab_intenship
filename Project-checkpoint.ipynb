# %% [markdown]
# ### IMPORT FUNCTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### LOAD THE DATA

# %%
data=pd.read_csv('EV_India.csv')

# %%
data
# Out:
#     Sr. No.                State Name Total Electric Vehicle  \
# 0         1  Andaman & Nicobar Island                    162
# 1         2             Andra Pradesh                    NaN
# 2         3         Arunachal Pradesh                     20
# 3         4                     Assam                  64766
# 4         5                     Bihar                  83335
# 5         6                Chandigarh                   2812
# 6         7              Chhattisgarh                  20966
# 7         8                     Delhi               1,56,393
# 8         9                       Goa                   3870
# 9        10                   Gujarat                  45272
# 10       11                   Haryana                  37035
# 11       12          Himachal Pradesh                   1175
# 12       13         Jammu and Kashmir                   2941
# 13       14                 Jharkhand                  16811
# ...

# %%
data.rename(columns={'State Name':'State_Name','Total Electric Vehicle':'Total_Electric_Vehicle','Total Non-Electric Vehicle':'Total_Non_Electric_Vehicle'},inplace=True)

# %% [markdown]
# ### BASIC CHECKS

# %%
data.head()
# Out:
#    Sr. No.                State_Name Total_Electric_Vehicle  \
# 0        1  Andaman & Nicobar Island                    162
# 1        2             Andra Pradesh                    NaN
# 2        3         Arunachal Pradesh                     20
# 3        4                     Assam                  64766
# 4        5                     Bihar                  83335
#
#   Total_Non_Electric_Vehicle        Total
# 0                   1,46,945     1,47,107
# 1                        NaN          NaN
# 2                   2,52,965     2,52,985
# 3                  46,77,053    47,41,819
# 4                1,04,07,078  1,04,90,413

# %%
data.tail()
# Out:
#     Sr. No.        State_Name Total_Electric_Vehicle  \
# 31       32           Tripura                   9262
# 32       33  UT of DNH and DD                    183
# 33       34       Uttarakhand                  31008
# 34       35     Uttar Pradesh               3,37,180
# 35       36       West Bengal                  48767
#
#    Total_Non_Electric_Vehicle        Total
# 31                   6,50,026     6,59,288
# 32                   3,07,671     3,07,854
# 33                  33,12,041    33,43,049
# 34                4,00,92,490  4,04,29,670
# 35                1,41,34,171  1,41,82,938

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sr. No.                     36 non-null     int64
#  1   State_Name                  36 non-null     object
#  2   Total_Electric_Vehicle      32 non-null     object
#  3   Total_Non_Electric_Vehicle  32 non-null     object
#  4   Total                       32 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %%
data.dtypes
# Out:
# Sr. No.                        int64
# State_Name                    object
# Total_Electric_Vehicle        object
# Total_Non_Electric_Vehicle    object
# Total                         object
# dtype: object

# %%
data.shape
# Out:
# (36, 5)

# %%
data.describe()
# Out:
#          Sr. No.
# count  36.000000
# mean   18.500000
# std    10.535654
# min     1.000000
# 25%     9.750000
# 50%    18.500000
# 75%    27.250000
# max    36.000000

# %%
data.describe(include='O')
# Out:
#                       State_Name Total_Electric_Vehicle  \
# count                         36                     32
# unique                        36                     31
# top     Andaman & Nicobar Island                     21
# freq                           1                      2
#
#        Total_Non_Electric_Vehicle     Total
# count                          32        32
# unique                         32        32
# top                      1,46,945  1,47,107
# freq                            1         1

# %% [markdown]
# ### CHECK THE NULL VALUES

# %%
data.isnull().sum()
# Out:
# Sr. No.                       0
# State_Name                    0
# Total_Electric_Vehicle        4
# Total_Non_Electric_Vehicle    4
# Total                         4
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Sr. No.                       0
# State_Name                    0
# Total_Electric_Vehicle        0
# Total_Non_Electric_Vehicle    0
# Total                         0
# dtype: int64

# %%
data['Total_Electric_Vehicle'] = data['Total_Electric_Vehicle'].str.replace(',', '').astype(int)
data['Total_Non_Electric_Vehicle'] = data['Total_Non_Electric_Vehicle'].str.replace(',', '').astype(int)
data['Total'] = data['Total'].str.replace(',', '').astype(int)

# %%
data.dtypes
# Out:
# Sr. No.                        int64
# State_Name                    object
# Total_Electric_Vehicle         int32
# Total_Non_Electric_Vehicle     int32
# Total                          int32
# dtype: object

# %%
data.drop(columns=['Sr. No.'],axis=1,inplace=True)
data.head()
# Out:
#                  State_Name  Total_Electric_Vehicle  \
# 0  Andaman & Nicobar Island                     162
# 2         Arunachal Pradesh                      20
# 3                     Assam                   64766
# 4                     Bihar                   83335
# 5                Chandigarh                    2812
#
#    Total_Non_Electric_Vehicle     Total
# 0                      146945    147107
# 2                      252965    252985
# 3                     4677053   4741819
# 4                    10407078  10490413
# 5                      746881    749693

# %% [markdown]
# ### EXPLORATARY ANALYSIS

# %%
sns.displot(x='Total_Electric_Vehicle',data=data,kde=True)

# %%
sns.displot(data=data,x='Total_Non_Electric_Vehicle',kde=True)

# %%
sns.displot(data=data,x='Total',kde=True)

# %%
sns.lineplot(x='Total_Electric_Vehicle',y='State_Name',data=data)
# Out:
# <Axes: xlabel='Total_Electric_Vehicle', ylabel='State_Name'>

# %%
sns.barplot(x='Total_Electric_Vehicle',y='State_Name',data=data)
# Out:
# <Axes: xlabel='Total_Electric_Vehicle', ylabel='State_Name'>

# %%
sns.barplot(x='Total_Non_Electric_Vehicle',y='State_Name',data=data)
# Out:
# <Axes: xlabel='Total_Non_Electric_Vehicle', ylabel='State_Name'>

# %%
sns.barplot(x='Total',y='State_Name',data=data)
# Out:
# <Axes: xlabel='Total', ylabel='State_Name'>

# %%
sns.pairplot(data)

# %%
s1=data[['Total_Electric_Vehicle','Total_Non_Electric_Vehicle','Total']]

# %% [markdown]
# ### CHECKING CORRELATION

# %%
plt.figure(figsize=(5,3))
sns.heatmap(s1.corr(),annot=True,cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# ### MODEL CREATION

# %%
x = s1.drop('Total',axis=1)
y=data.Total

# %%
x
# Out:
#     Total_Electric_Vehicle  Total_Non_Electric_Vehicle
# 0                      162                      146945
# 2                       20                      252965
# 3                    64766                     4677053
# 4                    83335                    10407078
# 5                     2812                      746881
# 6                    20966                     6836200
# 7                   156393                     7685600
# 8                     3870                     1071570
# 9                    45272                    20605484
# 10                   37035                    10778270
# 11                    1175                     1964754
# 12                    2941                     1869962
# 13                   16811                     6486937
# 14                  120532                    26870303
# 15                   30775                    15774078
# 16                      26                       38302
# ...

# %%
y
# Out:
# 0       147107
# 2       252985
# 3      4741819
# 4     10490413
# 5       749693
# 6      6857166
# 7      7841993
# 8      1075440
# 9     20650756
# 10    10815305
# 11     1965929
# 12     1872903
# 13     6503748
# 14    26990835
# 15    15804853
# 16       38328
# 19    31175636
# 20      499910
# 21      459050
# 22      315647
# 23      339187
# 24     9868444
# 25     1215884
# 26    12477823
# 27    17408726
# 28       97210
# 29    29924427
# 31      659288
# 32      307854
# 33     3343049
# 34    40429670
# 35    14182938
# Name: Total, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train.shape
# Out:
# (25, 2)

# %%
x_test.shape
# Out:
# (7, 2)

# %%
y_train.shape
# Out:
# (25,)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# ### USE TO LINEAR REGRESSION¶

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=LR.predict(x_test)
y_predict
# Out:
# array([3.3430490e+06, 3.8328000e+04, 1.7408726e+07, 4.9991000e+05,
#        2.0650756e+07, 1.0815305e+07, 4.0429670e+07])

# %%
LR.coef_
# Out:
# array([1., 1.])

# %%
LR.intercept_
# Out:
# -3.725290298461914e-09

# %%
LR.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ### MODEL EVALUTION

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2_regression=r2_score(y_test,y_predict)
r2_regression
# Out:
# 1.0

# %%
mse_regression=mean_squared_error(y_test,y_predict)
mse_regression
# Out:
# 4.0665356020615144e-17

# %%
import math
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 6.3769393928917925e-09

# %%
mae=mean_absolute_error(y_test,y_predict)
mae
# Out:
# 4.8208416306546755e-09

# %%
X = data.Total_Electric_Vehicle
Y = data.Total_Non_Electric_Vehicle
reg_line = LR.coef_*x+LR.intercept_
plt.scatter(X,Y)
plt.title("best fit line",{'size':15,'color':'blue'})
plt.xlabel('Total_Electric_Vehicle')
plt.ylabel('Total_Non_Electric_Vehicle')
plt.plot(X,reg_line,color='pink')
plt.show()

# %%
sns.distplot(y_test-y_predict)
# Out:
# <Axes: xlabel='Total', ylabel='Density'>

# %% [markdown]
# #### By using Linear Regression Model we got accuracy 0.99%

# %% [markdown]
# ### USE TO DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([ 1965929.,    97210., 14182938.,   459050., 14182938., 10490413.,
#        26990835.])

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
r2_dt = r2_score(y_test,y_predict)
r2_dt
# Out:
# 0.8124161822410632

# %%
import math
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 5792209.23796884

# %%
mae_dt=mean_absolute_error(y_test,y_predict)
mae_dt
# Out:
# 3562027.8571428573

# %% [markdown]
# By using Decision Regression Model we got accuracy score 0.90%

# %% [markdown]
# ### SVM REGRESSION

# %%
from sklearn.svm import SVR
model = SVR()
model.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1965930.31877754, 1965927.71122409, 1965940.72502063,
#        1965927.94762326, 1965940.22226132, 1965938.79369169,
#        1965936.59265141])

# %%
r2_svm = r2_score(y_test,y_predict)
r2_svm
# Out:
# 0.8124161822410632

# %%
import math
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 5792209.23796884

# %%
mae_svm=mean_absolute_error(y_test,y_predict)
mae_svm
# Out:
# 3562027.8571428573

# %% [markdown]
# #### By using SVM Regression model we got accuracy score 0.90%

# %% [markdown]
# ### USE TO RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict=rf.predict(x_test)
y_predict
# Out:
# array([ 3729634.55,   146623.3 , 16943675.43,   460025.17, 17748822.77,
#        10384275.19, 28765326.13])

# %%
rf.score(x_train,y_train)
# Out:
# 0.9950958867890688

# %% [markdown]
# ### HYPERPARAMETER TUNNING TECHNIQUE

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start=200,stop=2000,num=10)]
Bootstrap = [True,False]
max_feature=['auto','sqrt']
max_depth = [int(x) for x in np.linspace(10,110,2)]
max_depth.append(None)
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,4]

# %%
random_grid={'n_estimators': [10, 50, 100, 200],  # Replace with your desired values
    'bootstrap': [True, False],           # Replace with your desired values
    'max_features': ['auto', 'sqrt', 'log2'],  # Replace with your desired values
    'max_depth': [None, 10, 20, 30],       # Replace with your desired values
    'min_samples_split': [2, 5, 10],      # Replace with your desired values
    'min_samples_leaf': [1, 2, 4]         # Replace with your desired values
}
rf_Rgrss = RandomForestRegressor(random_state=42)
rf_cv = RandomizedSearchCV(estimator=rf_Rgrss,n_iter=100,cv=3,verbose=2,n_jobs=-1,
                          random_state=42,param_distributions=random_grid)
rf_cv.fit(x_train,y_train)
rf_best_params = rf_cv.best_params_
print(f"Best_parameters:{rf_best_params})")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best_parameters:{'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': True})

# %%
rf_Regressor = RandomForestRegressor(n_estimators=200, min_samples_split=2, min_samples_leaf=1,
                                     max_features='sqrt', max_depth=30, bootstrap=True)
rf_Regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=30, max_features='sqrt', n_estimators=200)

# %%
y_predict = rf_Regressor.predict(x_test)
y_predict
# Out:
# array([ 5911753.185,   151920.34 , 15984321.575,   373600.06 ,
#        16705253.61 , 11436459.535, 26991033.965])

# %%
r2_rf=r2_score(y_test,y_predict)
r2_rf
# Out:
# 0.8360926416295207

# %%
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 5414343.214669886

# %%
mae_rf=mean_absolute_error(y_test,y_predict)
mae_rf
# Out:
# 3176900.5500000003

# %% [markdown]
# #### By using Random Forest Regression we got accuracy score 0.76%

# %% [markdown]
# ### USE TO KNN REGRESSION

# %%
from sklearn.neighbors import KNeighborsRegressor
rmse=[]
for k in range(1,20):
    model=KNeighborsRegressor(n_neighbors=k)
    model.fit(x_train,y_train)
    predict=model.predict(x_test)
    error=np.sqrt(mean_squared_error(y_test,predict))
    rmse.append(error)
    print('rmse value for k=', k,'is:',error)
# Out:
# rmse value for k= 1 is: 4030233.6106392145
# rmse value for k= 2 is: 3862120.050657688
# rmse value for k= 3 is: 4408719.986588617
# rmse value for k= 4 is: 5835880.074483414
# rmse value for k= 5 is: 6635434.583358332
# rmse value for k= 6 is: 7194352.450193452
# rmse value for k= 7 is: 7812222.366427688
# rmse value for k= 8 is: 8369813.705633571
# rmse value for k= 9 is: 8934623.557418782
# rmse value for k= 10 is: 9293723.928407535
# rmse value for k= 11 is: 9760861.812228777
# rmse value for k= 12 is: 10115218.40481169
# rmse value for k= 13 is: 10625845.703738572
# rmse value for k= 14 is: 11073183.86388954
# rmse value for k= 15 is: 11509494.517800763
# rmse value for k= 16 is: 11897325.235520983
# rmse value for k= 17 is: 12260190.475750558
# rmse value for k= 18 is: 12597294.747958206
# rmse value for k= 19 is: 12914049.54335718

# %%
knn1 = KNeighborsRegressor(n_neighbors=5)
knn1.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predict=knn1.predict(x_test)
y_predict
# Out:
# array([ 2174395. ,   224160.6, 12564894.2,   416205.2, 19876175.2,
#        10972322.2, 23615737.8])

# %%
knn1.score(x_train,y_train)
# Out:
# 0.9437255105077154

# %%
r2_knn=r2_score(y_test,y_predict)
r2_knn
# Out:
# 0.7538240454747259

# %%
mse_knn=mean_squared_error(y_test,y_predict)
mse_knn
# Out:
# 44028992110027.76

# %%
import math
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 6635434.583358332

# %%
mae_knn=mean_absolute_error(y_test,y_predict)
mae_knn
# Out:
# 3432507.6285714284

# %%
sns.distplot(y_test-predict)
# Out:
# <Axes: xlabel='Total', ylabel='Density'>

# %% [markdown]
# ### EVALUTATION MODEL TO PLOT

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

models = {
    'Linear_Regression': LinearRegression(),
    'KNeighborsRegressor': KNeighborsRegressor(),
    'SVR': SVR(),
    'Decision_Tree': DecisionTreeRegressor(),
    'Random_Forest': RandomForestRegressor()
}

mean_squared_errors = {}
mean_absolute_errors = {}
r2_scores = {}
for name, model in zip(models.keys(),models.values()):
    model.fit(x_train, y_train)
    y_predict = model.predict(x_test)
    mse = mean_squared_error(y_test, y_predict)
    mae = mean_absolute_error(y_test, y_predict)
    r2score = r2_score(y_test, y_predict)

    mean_squared_errors[name] = mse
    mean_absolute_errors[name] = mae
    r2_scores[name] = r2score

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 15))

ax1.bar(mean_squared_errors.keys(), mean_squared_errors.values(), color='k')
ax1.set_ylabel('Mean Squared Error')

ax2.bar(mean_absolute_errors.keys(), mean_absolute_errors.values(), color='r')
ax2.set_ylabel('Mean Absolute Error')

ax3.bar(r2_scores.keys(), r2_scores.values(), color='b')
ax3.set_ylabel('R-squared')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Finally, I selected the tuned Support Vector Regressor model as our final model, which gave the best results in terms of r2-score.
